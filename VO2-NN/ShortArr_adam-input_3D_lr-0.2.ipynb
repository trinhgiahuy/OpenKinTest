# %%
import tensorflow as tf
import scipy.io as sio 
import numpy as np
import pandas as pd
#import tensorflow as tf
#from keras import Model
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Input, Bidirectional
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model

from tensorflow.python.client import device_lib

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU' or x.device_type == 'CPU']



i=sio.loadmat('inputFeatures.mat')
print(sorted(i.keys()))

TTest=i['TTest']
#print(TTest)

print("TTest:",TTest.shape)
#print(TTest)
#print(type(TTest))

TTrain=i['TTrain']
print("TTrain:",TTrain.shape)
# print(TTrain)

XTrain=i['XTrain']
print("XTrain:",XTrain.shape)
#print(XTrain)
#print(type(XTrain))

XTest=i['XTest']
print("XTest:",XTest.shape)
# print(XTest)
# print(type(XTest))

XTrain=XTrain.reshape(-1)
TTrain=TTrain.reshape(-1)
XTest=XTest.reshape(-1)
TTest=TTest.reshape(-1)

#print(XTrain)

#column_series = pd.DataFrame(np.array(XTrain))
#print(column_series[0])


data=np.transpose(np.array(XTrain[0]))
data1=np.transpose(np.array(XTrain[1]))
test=np.stack((data,data1),axis=0)
data2=np.transpose(np.array(XTrain[2]))
# a=[]
# a.append(data)
# a.append(data1)
# a.append(data2)
# #print(a)
# a=np.stack(a)
#print(a)
#print(a.shape)


##________________________________________TEST
test=np.transpose(XTrain).reshape(-1)
#print(test)
list_test=[]
for i in range(len(test)):
    test[i]=np.transpose(np.array(test[i]))
    list_test.append(test[i])

list_test=np.vstack(list_test)
df=pd.DataFrame(list_test)
df.columns = ['C1','C2','C3','C4']
print(df)
normalized_df=(df-df.mean())/df.std()
#print(normalized_df.shape)
#________________________________________
print(normalized_df)
normalized_df=normalized_df.to_numpy()

# FOR 2D INPUT - RESHAPE TO 3D AS BELOW
#normalized_df=normalized_df.reshape(67950,1,4)
#print(normalized_df)
#TTrain=np.repeat(TTrain,50)

listTest=[]
i=0
while i < (len(normalized_df)):
    listTest.append(normalized_df[i:i+50])
    i=i+50

#print(listTest)
listTest=np.stack(listTest)


testArr=[]
for i in range(len(XTest)):
    testArr.append(np.transpose(np.array(XTest[i])))

testArr=np.stack(testArr)


length = 50
n_features = 4
model = Sequential()
model.add(LSTM(150,input_shape=(length,n_features)))
#model.add(tf.keras.layers.RNN(tf.keras.layers.LSTMCell(150)),input_shape=(length,n_features))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['acc'])
opt=Adam(learning_rate=0.02)
model.compile(optimizer=opt, loss='mean_squared_logarithmic_error')
model.summary()
with tf.device('/gpu:0'):
    model.fit(listTest,TTrain,epochs=100,batch_size=10,verbose=2,validation_data=(testArr,TTest))


with tf.device('/cpu:0'):
    Y_hat=model.predict(testArr)

#print(Y_hat)
TTest=TTest.reshape(len(TTest),1)
#print(np.array(TTest))

dataResult=np.concatenate((Y_hat,TTest),axis=1)
#print(dataResult)
# Out:
# ['TTest', 'TTrain', 'XTest', 'XTrain', '__globals__', '__header__', '__version__']
# TTest: (340, 1)
# TTrain: (1359, 1)
# XTrain: (1359, 1)
# XTest: (340, 1)
#              C1        C2      C3        C4
# 0      2.594557  0.459191  0.3900  0.068406
# 1      2.570753  0.496237  0.4050  0.080021
# 2      2.553465  0.533884  0.3825  0.069378
# 3      2.585183  0.476851  0.3975  0.079567
# 4      2.589196  0.526986  0.3825  0.065496
# ...         ...       ...     ...       ...
# 67945  3.516776  0.437440  0.3975  0.080801
# 67946  3.383230  0.659559  0.3825  0.072998
# 67947  3.425420  0.499233  0.3975  0.083357
# 67948  3.330528  0.516398  0.3725  0.075701
# 67949  3.444686  0.457105  0.3950  0.079806
#
# [67950 rows x 4 columns]
#              C1        C2        C3        C4
# 0      0.323124  0.251716 -0.079844 -0.000175
# 1      0.298567  0.479955 -0.075502  0.026230
# 2      0.280732  0.711891 -0.082015  0.002033
# 3      0.313454  0.360520 -0.077673  0.025197
# 4      0.317594  0.669393 -0.082015 -0.006793
# ...         ...       ...       ...       ...
# 67945  1.274541  0.117707 -0.077673  0.028002
# 67946  1.136767  1.486165 -0.082015  0.010264
# 67947  1.180292  0.498413 -0.077673  0.033813
# 67948  1.082396  0.604162 -0.084910  0.016407
# 67949  1.200168  0.238863 -0.078396  0.025741
#
# [67950 rows x 4 columns]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150)               93000
#
#  dense (Dense)               (None, 1)                 151
#
# =================================================================
# Total params: 93,151
# Trainable params: 93,151
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 136/136 - 5s - loss: 1.7962 - val_loss: 0.1761 - 5s/epoch - 37ms/step
# Epoch 2/100
# 136/136 - 1s - loss: 0.1614 - val_loss: 0.1697 - 1s/epoch - 8ms/step
# Epoch 3/100
# 136/136 - 1s - loss: 0.1404 - val_loss: 0.1737 - 1s/epoch - 8ms/step
# Epoch 4/100
# 136/136 - 1s - loss: 0.1644 - val_loss: 0.1619 - 1s/epoch - 8ms/step
# Epoch 5/100
# 136/136 - 1s - loss: 0.1494 - val_loss: 0.1735 - 1s/epoch - 9ms/step
# Epoch 6/100
# 136/136 - 1s - loss: 0.1441 - val_loss: 0.1963 - 1s/epoch - 11ms/step
# Epoch 7/100
# 136/136 - 1s - loss: 0.1394 - val_loss: 0.2089 - 1s/epoch - 10ms/step
# Epoch 8/100
# 136/136 - 1s - loss: 0.1326 - val_loss: 0.1979 - 1s/epoch - 10ms/step
# Epoch 9/100
# 136/136 - 1s - loss: 0.1352 - val_loss: 0.1968 - 1s/epoch - 8ms/step
# Epoch 10/100
# 136/136 - 1s - loss: 0.1345 - val_loss: 0.2239 - 1s/epoch - 8ms/step
# Epoch 11/100
# 136/136 - 1s - loss: 0.1321 - val_loss: 0.1912 - 971ms/epoch - 7ms/step
# Epoch 12/100
# 136/136 - 1s - loss: 0.1350 - val_loss: 0.1625 - 961ms/epoch - 7ms/step
# Epoch 13/100
# 136/136 - 1s - loss: 0.1357 - val_loss: 0.1895 - 1s/epoch - 8ms/step
# Epoch 14/100
# 136/136 - 1s - loss: 0.1325 - val_loss: 0.1928 - 1s/epoch - 8ms/step
# Epoch 15/100
# 136/136 - 1s - loss: 0.1334 - val_loss: 0.2008 - 1s/epoch - 9ms/step
# Epoch 16/100
# 136/136 - 1s - loss: 0.1398 - val_loss: 0.1718 - 1s/epoch - 8ms/step
# Epoch 17/100
# 136/136 - 1s - loss: 0.1350 - val_loss: 0.2000 - 1s/epoch - 9ms/step
# Epoch 18/100
# 136/136 - 1s - loss: 0.1346 - val_loss: 0.1817 - 1s/epoch - 8ms/step
# Epoch 19/100
# 136/136 - 1s - loss: 0.1334 - val_loss: 0.1891 - 1s/epoch - 8ms/step
# Epoch 20/100
# 136/136 - 1s - loss: 0.1363 - val_loss: 0.1807 - 1s/epoch - 7ms/step
# Epoch 21/100
# 136/136 - 1s - loss: 0.1361 - val_loss: 0.2263 - 1s/epoch - 7ms/step
# Epoch 22/100
# 136/136 - 1s - loss: 0.1359 - val_loss: 0.1862 - 1s/epoch - 7ms/step
# Epoch 23/100
# 136/136 - 1s - loss: 0.1337 - val_loss: 0.1722 - 997ms/epoch - 7ms/step
# Epoch 24/100
# 136/136 - 1s - loss: 0.1364 - val_loss: 0.1827 - 1s/epoch - 7ms/step
# Epoch 25/100
# 136/136 - 1s - loss: 0.1345 - val_loss: 0.1976 - 1s/epoch - 7ms/step
# Epoch 26/100
# 136/136 - 1s - loss: 0.1350 - val_loss: 0.1771 - 1s/epoch - 7ms/step
# Epoch 27/100
# 136/136 - 1s - loss: 0.1359 - val_loss: 0.2023 - 987ms/epoch - 7ms/step
# Epoch 28/100
# 136/136 - 1s - loss: 0.1347 - val_loss: 0.2176 - 1s/epoch - 8ms/step
# Epoch 29/100
# 136/136 - 1s - loss: 0.1347 - val_loss: 0.1770 - 1s/epoch - 8ms/step
# Epoch 30/100
# 136/136 - 1s - loss: 0.1346 - val_loss: 0.1880 - 1s/epoch - 8ms/step
# Epoch 31/100
# 136/136 - 1s - loss: 0.1209 - val_loss: 0.2248 - 1s/epoch - 8ms/step
# Epoch 32/100
# 136/136 - 1s - loss: 0.3277 - val_loss: 0.1910 - 1s/epoch - 8ms/step
# Epoch 33/100
# 136/136 - 1s - loss: 0.1061 - val_loss: 0.1953 - 1s/epoch - 8ms/step
# Epoch 34/100
# 136/136 - 1s - loss: 0.0985 - val_loss: 0.1842 - 1s/epoch - 10ms/step
# Epoch 35/100
# 136/136 - 1s - loss: 0.1015 - val_loss: 0.1710 - 1s/epoch - 8ms/step
# Epoch 36/100
# 136/136 - 1s - loss: 0.0977 - val_loss: 0.1847 - 1s/epoch - 10ms/step
# Epoch 37/100
# 136/136 - 1s - loss: 0.0930 - val_loss: 0.1942 - 1s/epoch - 7ms/step
# Epoch 38/100
# 136/136 - 1s - loss: 0.0940 - val_loss: 0.1935 - 1s/epoch - 7ms/step
# Epoch 39/100
# 136/136 - 1s - loss: 0.0900 - val_loss: 0.1870 - 1s/epoch - 7ms/step
# Epoch 40/100
# 136/136 - 1s - loss: 0.0896 - val_loss: 0.1975 - 1s/epoch - 8ms/step
# Epoch 41/100
# 136/136 - 1s - loss: 0.0934 - val_loss: 0.1839 - 983ms/epoch - 7ms/step
# Epoch 42/100
# 136/136 - 1s - loss: 0.0893 - val_loss: 0.1901 - 1s/epoch - 7ms/step
# Epoch 43/100
# 136/136 - 1s - loss: 0.0875 - val_loss: 0.2054 - 1s/epoch - 9ms/step
# Epoch 44/100
# 136/136 - 1s - loss: 0.0878 - val_loss: 0.2033 - 1s/epoch - 8ms/step
# Epoch 45/100
# 136/136 - 1s - loss: 0.0866 - val_loss: 0.2142 - 1s/epoch - 8ms/step
# Epoch 46/100
# 136/136 - 1s - loss: 0.0918 - val_loss: 0.2437 - 1s/epoch - 8ms/step
# Epoch 47/100
# 136/136 - 1s - loss: 0.0908 - val_loss: 0.2133 - 1s/epoch - 9ms/step
# Epoch 48/100
# 136/136 - 1s - loss: 0.0879 - val_loss: 0.2400 - 1s/epoch - 8ms/step
# Epoch 49/100
# 136/136 - 1s - loss: 0.0837 - val_loss: 0.2684 - 1s/epoch - 8ms/step
# Epoch 50/100
# 136/136 - 1s - loss: 0.0852 - val_loss: 0.2057 - 1s/epoch - 8ms/step
# Epoch 51/100
# 136/136 - 1s - loss: 0.0843 - val_loss: 0.2261 - 995ms/epoch - 7ms/step
# Epoch 52/100
# 136/136 - 1s - loss: 0.0807 - val_loss: 0.2291 - 1s/epoch - 7ms/step
# Epoch 53/100
# 136/136 - 1s - loss: 0.0778 - val_loss: 0.2332 - 1s/epoch - 8ms/step
# Epoch 54/100
# 136/136 - 1s - loss: 0.0799 - val_loss: 0.2289 - 1s/epoch - 8ms/step
# Epoch 55/100
# 136/136 - 1s - loss: 0.0784 - val_loss: 0.2500 - 1s/epoch - 8ms/step
# Epoch 56/100
# 136/136 - 1s - loss: 0.0779 - val_loss: 0.2140 - 1s/epoch - 8ms/step
# Epoch 57/100
# 136/136 - 1s - loss: 0.0869 - val_loss: 0.2367 - 1s/epoch - 9ms/step
# Epoch 58/100
# 136/136 - 1s - loss: 0.0792 - val_loss: 0.2402 - 1s/epoch - 9ms/step
# Epoch 59/100
# 136/136 - 1s - loss: 0.0774 - val_loss: 0.3177 - 1s/epoch - 8ms/step
# Epoch 60/100
# 136/136 - 1s - loss: 0.0750 - val_loss: 0.3104 - 1s/epoch - 7ms/step
# Epoch 61/100
# 136/136 - 1s - loss: 0.0768 - val_loss: 0.2406 - 1s/epoch - 9ms/step
# Epoch 62/100
# 136/136 - 1s - loss: 0.0750 - val_loss: 0.2196 - 1s/epoch - 7ms/step
# Epoch 63/100
# 136/136 - 1s - loss: 0.0753 - val_loss: 0.2442 - 1000ms/epoch - 7ms/step
# Epoch 64/100
# 136/136 - 1s - loss: 0.0712 - val_loss: 0.2454 - 1s/epoch - 8ms/step
# Epoch 65/100
# 136/136 - 1s - loss: 0.0726 - val_loss: 0.2513 - 1s/epoch - 7ms/step
# Epoch 66/100
# 136/136 - 1s - loss: 0.0703 - val_loss: 0.2891 - 1s/epoch - 7ms/step
# Epoch 67/100
# 136/136 - 1s - loss: 0.0732 - val_loss: 0.3164 - 1s/epoch - 7ms/step
# Epoch 68/100
# 136/136 - 1s - loss: 0.0851 - val_loss: 0.3481 - 1s/epoch - 7ms/step
# Epoch 69/100
# 136/136 - 1s - loss: 0.1626 - val_loss: 0.1889 - 1s/epoch - 7ms/step
# Epoch 70/100
# 136/136 - 1s - loss: 0.1074 - val_loss: 0.2065 - 1s/epoch - 7ms/step
# Epoch 71/100
# 136/136 - 1s - loss: 0.0886 - val_loss: 0.1889 - 1s/epoch - 8ms/step
# Epoch 72/100
# 136/136 - 1s - loss: 0.0835 - val_loss: 0.2392 - 1s/epoch - 7ms/step
# Epoch 73/100
# 136/136 - 1s - loss: 0.0812 - val_loss: 0.5048 - 1s/epoch - 9ms/step
# Epoch 74/100
# 136/136 - 1s - loss: 0.0812 - val_loss: 0.2358 - 1s/epoch - 8ms/step
# Epoch 75/100
# 136/136 - 1s - loss: 0.0770 - val_loss: 0.2751 - 1s/epoch - 8ms/step
# Epoch 76/100
# 136/136 - 1s - loss: 0.0743 - val_loss: 0.2909 - 1s/epoch - 8ms/step
# Epoch 77/100
# 136/136 - 1s - loss: 0.0696 - val_loss: 0.2936 - 1s/epoch - 8ms/step
# Epoch 78/100
# 136/136 - 1s - loss: 0.0689 - val_loss: 0.3609 - 1s/epoch - 8ms/step
# Epoch 79/100
# 136/136 - 1s - loss: 0.0720 - val_loss: 0.4427 - 1s/epoch - 8ms/step
# Epoch 80/100
# 136/136 - 1s - loss: 0.0711 - val_loss: 0.3249 - 1s/epoch - 8ms/step
# Epoch 81/100
# 136/136 - 1s - loss: 0.0673 - val_loss: 0.3635 - 1s/epoch - 8ms/step
# Epoch 82/100
# 136/136 - 1s - loss: 0.0643 - val_loss: 0.3287 - 1s/epoch - 7ms/step
# Epoch 83/100
# 136/136 - 1s - loss: 0.0681 - val_loss: 0.3839 - 1s/epoch - 8ms/step
# Epoch 84/100
# 136/136 - 1s - loss: 0.0690 - val_loss: 0.4289 - 1s/epoch - 7ms/step
# Epoch 85/100
# 136/136 - 1s - loss: 0.0709 - val_loss: 0.5277 - 988ms/epoch - 7ms/step
# Epoch 86/100
# 136/136 - 1s - loss: 0.0690 - val_loss: 0.8974 - 979ms/epoch - 7ms/step
# Epoch 87/100
# 136/136 - 1s - loss: 0.0775 - val_loss: 0.5434 - 1s/epoch - 7ms/step
# Epoch 88/100
# 136/136 - 1s - loss: 0.0694 - val_loss: 0.6050 - 1s/epoch - 8ms/step
# Epoch 89/100
# 136/136 - 1s - loss: 0.0716 - val_loss: 0.7099 - 1s/epoch - 8ms/step
# Epoch 90/100
# 136/136 - 1s - loss: 0.0666 - val_loss: 0.5643 - 988ms/epoch - 7ms/step
# Epoch 91/100
# 136/136 - 1s - loss: 0.0658 - val_loss: 0.5870 - 961ms/epoch - 7ms/step
# Epoch 92/100
# 136/136 - 1s - loss: 0.0686 - val_loss: 0.3639 - 977ms/epoch - 7ms/step
# Epoch 93/100
# 136/136 - 1s - loss: 0.0659 - val_loss: 0.3353 - 1s/epoch - 7ms/step
# Epoch 94/100
# 136/136 - 1s - loss: 0.0623 - val_loss: 0.4898 - 994ms/epoch - 7ms/step
# Epoch 95/100
# 136/136 - 1s - loss: 0.0603 - val_loss: 0.3527 - 1s/epoch - 7ms/step
# Epoch 96/100
# 136/136 - 1s - loss: 0.0635 - val_loss: 0.4437 - 1s/epoch - 7ms/step
# Epoch 97/100
# 136/136 - 1s - loss: 0.0611 - val_loss: 0.3303 - 963ms/epoch - 7ms/step
# Epoch 98/100
# 136/136 - 1s - loss: 0.0596 - val_loss: 0.5466 - 995ms/epoch - 7ms/step
# Epoch 99/100
# 136/136 - 1s - loss: 0.0612 - val_loss: 0.5224 - 995ms/epoch - 7ms/step
# Epoch 100/100
# 136/136 - 1s - loss: 0.0612 - val_loss: 0.3436 - 965ms/epoch - 7ms/step
# 11/11 [==============================] - 0s 10ms/step

# %%
print("Evaluate on test data")
results = model.evaluate(testArr,TTest, batch_size=10) 
print("test loss", results)

get_available_devices()
# Out:
# Evaluate on test data
# 34/34 [==============================] - 1s 4ms/step - loss: 0.3436
# test loss 0.34362056851387024
# ['/device:CPU:0', '/device:GPU:0']

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.plot(TTest,color='green',label='Actual')
plt.plot(Y_hat,color='blue',label='Predicted')
plt.xlabel('Number')
plt.ylabel('VO2max')
plt.title('Actual vs Predicted')
plt.legend()
#plt.figure(figsize=(100,100))

#plt.show()
fig = plt.gcf()
fig.set_size_inches(20.5, 10.5)
fig.savefig('test2png.png', dpi=150)

# %%
#pd.DataFrame(dataResult).to_csv('sample.csv')
