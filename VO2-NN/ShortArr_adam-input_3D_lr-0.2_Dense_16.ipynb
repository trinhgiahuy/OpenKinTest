# %%
import tensorflow as tf
import scipy.io as sio 
import numpy as np
import pandas as pd
#import tensorflow as tf
#from keras import Model
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.optimizers import Adam
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Input, Bidirectional
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model

from tensorflow.python.client import device_lib

gpu_devices = tf.config.experimental.list_physical_devices('GPU')
for device in gpu_devices:
    tf.config.experimental.set_memory_growth(device, True)
    
def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU' or x.device_type == 'CPU']



i=sio.loadmat('inputFeatures.mat')
print(sorted(i.keys()))

TTest=i['TTest']
#print(TTest)

print("TTest:",TTest.shape)
#print(TTest)
#print(type(TTest))

TTrain=i['TTrain']
print("TTrain:",TTrain.shape)
# print(TTrain)

XTrain=i['XTrain']
print("XTrain:",XTrain.shape)
#print(XTrain)
#print(type(XTrain))

XTest=i['XTest']
print("XTest:",XTest.shape)
# print(XTest)
# print(type(XTest))

XTrain=XTrain.reshape(-1)
TTrain=TTrain.reshape(-1)
XTest=XTest.reshape(-1)
TTest=TTest.reshape(-1)

#print(XTrain)

#column_series = pd.DataFrame(np.array(XTrain))
#print(column_series[0])


data=np.transpose(np.array(XTrain[0]))
data1=np.transpose(np.array(XTrain[1]))
test=np.stack((data,data1),axis=0)
data2=np.transpose(np.array(XTrain[2]))
# a=[]
# a.append(data)
# a.append(data1)
# a.append(data2)
# #print(a)
# a=np.stack(a)
#print(a)
#print(a.shape)


##________________________________________TEST
test=np.transpose(XTrain).reshape(-1)
#print(test)
list_test=[]
for i in range(len(test)):
    test[i]=np.transpose(np.array(test[i]))
    list_test.append(test[i])

list_test=np.vstack(list_test)
df=pd.DataFrame(list_test)
df.columns = ['C1','C2','C3','C4']
print(df)
normalized_df=(df-df.mean())/df.std()
#print(normalized_df.shape)
#________________________________________
print(normalized_df)
normalized_df=normalized_df.to_numpy()

# FOR 2D INPUT - RESHAPE TO 3D AS BELOW
#normalized_df=normalized_df.reshape(67950,1,4)
#print(normalized_df)
#TTrain=np.repeat(TTrain,50)

listTest=[]
i=0
while i < (len(normalized_df)):
    listTest.append(normalized_df[i:i+50])
    i=i+50

#print(listTest)
listTest=np.stack(listTest)


testArr=[]
for i in range(len(XTest)):
    testArr.append(np.transpose(np.array(XTest[i])))

testArr=np.stack(testArr)


length = 50
n_features = 4
model = Sequential()
model.add(LSTM(150,input_shape=(length,n_features)))
#model.add(tf.keras.layers.RNN(tf.keras.layers.LSTMCell(150)),input_shape=(length,n_features))
model.add(Dense(16, activation= 'elu', kernel_initializer='normal'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['acc'])
opt=Adam(learning_rate=0.02)
model.compile(optimizer=opt, loss='mean_squared_logarithmic_error')
model.summary()
with tf.device('/gpu:0'):
    model.fit(listTest,TTrain,epochs=100,batch_size=10,verbose=1,validation_data=(testArr,TTest))


with tf.device('/cpu:0'):
    Y_hat=model.predict(testArr)

#print(Y_hat)
TTest=TTest.reshape(len(TTest),1)
#print(np.array(TTest))

dataResult=np.concatenate((Y_hat,TTest),axis=1)
#print(dataResult)
# Out:
# ['TTest', 'TTrain', 'XTest', 'XTrain', '__globals__', '__header__', '__version__']
# TTest: (340, 1)
# TTrain: (1359, 1)
# XTrain: (1359, 1)
# XTest: (340, 1)
#              C1        C2      C3        C4
# 0      2.594557  0.459191  0.3900  0.068406
# 1      2.570753  0.496237  0.4050  0.080021
# 2      2.553465  0.533884  0.3825  0.069378
# 3      2.585183  0.476851  0.3975  0.079567
# 4      2.589196  0.526986  0.3825  0.065496
# ...         ...       ...     ...       ...
# 67945  3.516776  0.437440  0.3975  0.080801
# 67946  3.383230  0.659559  0.3825  0.072998
# 67947  3.425420  0.499233  0.3975  0.083357
# 67948  3.330528  0.516398  0.3725  0.075701
# 67949  3.444686  0.457105  0.3950  0.079806
#
# [67950 rows x 4 columns]
#              C1        C2        C3        C4
# 0      0.323124  0.251716 -0.079844 -0.000175
# 1      0.298567  0.479955 -0.075502  0.026230
# 2      0.280732  0.711891 -0.082015  0.002033
# 3      0.313454  0.360520 -0.077673  0.025197
# 4      0.317594  0.669393 -0.082015 -0.006793
# ...         ...       ...       ...       ...
# 67945  1.274541  0.117707 -0.077673  0.028002
# 67946  1.136767  1.486165 -0.082015  0.010264
# 67947  1.180292  0.498413 -0.077673  0.033813
# 67948  1.082396  0.604162 -0.084910  0.016407
# 67949  1.200168  0.238863 -0.078396  0.025741
#
# [67950 rows x 4 columns]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150)               93000
#
#  dense (Dense)               (None, 16)                2416
#
#  dense_1 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 95,433
# Trainable params: 95,433
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 136/136 [==============================] - 4s 10ms/step - loss: 0.8581 - val_loss: 5.3764
# Epoch 2/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1584 - val_loss: 5.4045
# Epoch 3/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1449 - val_loss: 5.4545
# Epoch 4/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1369 - val_loss: 5.2681
# Epoch 5/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1335 - val_loss: 5.3835
# Epoch 6/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1301 - val_loss: 5.2878
# Epoch 7/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1216 - val_loss: 5.4735
# Epoch 8/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1267 - val_loss: 5.9084
# Epoch 9/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1220 - val_loss: 5.5000
# Epoch 10/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.3650 - val_loss: 0.3476
# Epoch 11/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1210 - val_loss: 0.2632
# Epoch 12/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.1071 - val_loss: 0.2259
# Epoch 13/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1223 - val_loss: 0.2488
# Epoch 14/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1096 - val_loss: 0.2195
# Epoch 15/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0998 - val_loss: 0.2188
# Epoch 16/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0982 - val_loss: 0.1812
# Epoch 17/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0975 - val_loss: 0.2298
# Epoch 18/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0934 - val_loss: 0.1757
# Epoch 19/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0908 - val_loss: 0.1999
# Epoch 20/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0905 - val_loss: 0.1946
# Epoch 21/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0896 - val_loss: 0.2009
# Epoch 22/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0879 - val_loss: 0.1871
# Epoch 23/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0877 - val_loss: 0.2350
# Epoch 24/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0873 - val_loss: 0.2001
# Epoch 25/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0862 - val_loss: 0.1835
# Epoch 26/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0869 - val_loss: 0.1713
# Epoch 27/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0827 - val_loss: 0.2120
# Epoch 28/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0845 - val_loss: 0.1894
# Epoch 29/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0838 - val_loss: 0.2284
# Epoch 30/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0829 - val_loss: 0.2131
# Epoch 31/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0825 - val_loss: 0.2161
# Epoch 32/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0800 - val_loss: 0.2088
# Epoch 33/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0818 - val_loss: 0.2052
# Epoch 34/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0832 - val_loss: 0.2337
# Epoch 35/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0807 - val_loss: 0.5071
# Epoch 36/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0812 - val_loss: 2.8162
# Epoch 37/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0795 - val_loss: 1.8673
# Epoch 38/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0779 - val_loss: 0.2705
# Epoch 39/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0778 - val_loss: 0.6208
# Epoch 40/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0787 - val_loss: 2.7747
# Epoch 41/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0782 - val_loss: 1.3342
# Epoch 42/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0778 - val_loss: 2.6279
# Epoch 43/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0725 - val_loss: 2.8863
# Epoch 44/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.1002 - val_loss: 0.1673
# Epoch 45/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0899 - val_loss: 0.2024
# Epoch 46/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0872 - val_loss: 0.2011
# Epoch 47/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0847 - val_loss: 0.2059
# Epoch 48/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0888 - val_loss: 0.1934
# Epoch 49/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0853 - val_loss: 0.1828
# Epoch 50/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0857 - val_loss: 0.1826
# Epoch 51/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0823 - val_loss: 0.2057
# Epoch 52/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0811 - val_loss: 0.2054
# Epoch 53/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0824 - val_loss: 0.1900
# Epoch 54/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0824 - val_loss: 0.2192
# Epoch 55/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0810 - val_loss: 0.2291
# Epoch 56/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0803 - val_loss: 0.3685
# Epoch 57/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0817 - val_loss: 0.2480
# Epoch 58/100
# 136/136 [==============================] - 1s 10ms/step - loss: 0.0748 - val_loss: 0.3232
# Epoch 59/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0772 - val_loss: 0.3099
# Epoch 60/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0725 - val_loss: 0.3300
# Epoch 61/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0731 - val_loss: 0.3690
# Epoch 62/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0745 - val_loss: 0.2696
# Epoch 63/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0691 - val_loss: 0.3380
# Epoch 64/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0708 - val_loss: 0.3370
# Epoch 65/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0744 - val_loss: 0.2462
# Epoch 66/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0700 - val_loss: 0.2762
# Epoch 67/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0775 - val_loss: 0.3288
# Epoch 68/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0752 - val_loss: 0.4172
# Epoch 69/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0651 - val_loss: 0.3844
# Epoch 70/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0665 - val_loss: 0.2917
# Epoch 71/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0671 - val_loss: 0.2466
# Epoch 72/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0633 - val_loss: 0.2380
# Epoch 73/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0614 - val_loss: 0.2785
# Epoch 74/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0617 - val_loss: 0.2774
# Epoch 75/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0597 - val_loss: 0.4424
# Epoch 76/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0734 - val_loss: 0.2299
# Epoch 77/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0805 - val_loss: 0.2559
# Epoch 78/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0855 - val_loss: 0.3981
# Epoch 79/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0819 - val_loss: 0.2765
# Epoch 80/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0710 - val_loss: 0.3048
# Epoch 81/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0642 - val_loss: 0.3011
# Epoch 82/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0751 - val_loss: 0.3002
# Epoch 83/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0709 - val_loss: 0.2994
# Epoch 84/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0644 - val_loss: 0.2720
# Epoch 85/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0627 - val_loss: 0.2224
# Epoch 86/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0562 - val_loss: 0.3000
# Epoch 87/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0607 - val_loss: 0.2270
# Epoch 88/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0547 - val_loss: 0.4158
# Epoch 89/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0604 - val_loss: 0.2796
# Epoch 90/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0673 - val_loss: 0.2312
# Epoch 91/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0912 - val_loss: 0.2174
# Epoch 92/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0877 - val_loss: 0.2091
# Epoch 93/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0783 - val_loss: 0.1701
# Epoch 94/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0790 - val_loss: 0.1673
# Epoch 95/100
# 136/136 [==============================] - 1s 7ms/step - loss: 0.0771 - val_loss: 0.1839
# Epoch 96/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0741 - val_loss: 0.1851
# Epoch 97/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0768 - val_loss: 0.1776
# Epoch 98/100
# 136/136 [==============================] - 1s 9ms/step - loss: 0.0747 - val_loss: 0.1767
# Epoch 99/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0705 - val_loss: 0.1864
# Epoch 100/100
# 136/136 [==============================] - 1s 8ms/step - loss: 0.0702 - val_loss: 0.2111
# 11/11 [==============================] - 0s 10ms/step

# %%
print("Evaluate on test data")
results = model.evaluate(testArr,TTest, batch_size=10) 
print("test loss", results)

get_available_devices()
# Out:
# Evaluate on test data
# 34/34 [==============================] - 1s 5ms/step - loss: 0.2111
# test loss 0.2110852152109146
# ['/device:CPU:0', '/device:GPU:0']

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.plot(TTest,color='green',label='Actual')
plt.plot(Y_hat,color='blue',label='Predicted')
plt.xlabel('Number')
plt.ylabel('VO2max')
plt.title('Actual vs Predicted')
plt.legend()
#plt.figure(figsize=(100,100))

#plt.show()
fig = plt.gcf()
fig.set_size_inches(20.5, 10.5)
fig.savefig('test2png.png', dpi=150)

# %%
#pd.DataFrame(dataResult).to_csv('sample.csv')
