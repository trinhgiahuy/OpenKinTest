# %%
import tensorflow as tf
import scipy.io as sio 
import numpy as np
import pandas as pd
#import tensorflow as tf
#from keras import Model
from tensorflow.keras.models import Model
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dense
from keras.layers import Input, Bidirectional
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Model

from tensorflow.python.client import device_lib

def get_available_devices():
    local_device_protos = device_lib.list_local_devices()
    return [x.name for x in local_device_protos if x.device_type == 'GPU' or x.device_type == 'CPU']



i=sio.loadmat('inputFeatures.mat')
print(sorted(i.keys()))

TTest=i['TTest']
#print(TTest)

print("TTest:",TTest.shape)
#print(TTest)
#print(type(TTest))

TTrain=i['TTrain']
print("TTrain:",TTrain.shape)
# print(TTrain)

XTrain=i['XTrain']
print("XTrain:",XTrain.shape)
#print(XTrain)
#print(type(XTrain))

XTest=i['XTest']
print("XTest:",XTest.shape)
# print(XTest)
# print(type(XTest))

XTrain=XTrain.reshape(-1)
TTrain=TTrain.reshape(-1)
XTest=XTest.reshape(-1)
TTest=TTest.reshape(-1)

#print(XTrain)

#column_series = pd.DataFrame(np.array(XTrain))
#print(column_series[0])


data=np.transpose(np.array(XTrain[0]))
data1=np.transpose(np.array(XTrain[1]))
test=np.stack((data,data1),axis=0)
data2=np.transpose(np.array(XTrain[2]))
# a=[]
# a.append(data)
# a.append(data1)
# a.append(data2)
# #print(a)
# a=np.stack(a)
#print(a)
#print(a.shape)


##________________________________________TEST
test=np.transpose(XTrain).reshape(-1)
#print(test)
list_test=[]
for i in range(len(test)):
    test[i]=np.transpose(np.array(test[i]))
    list_test.append(test[i])

list_test=np.vstack(list_test)
df=pd.DataFrame(list_test)
df.columns = ['C1','C2','C3','C4']
print(df)
normalized_df=(df-df.mean())/df.std()
#print(normalized_df.shape)
#________________________________________
print(normalized_df)
normalized_df=normalized_df.to_numpy()

# FOR 2D INPUT - RESHAPE TO 3D AS BELOW
#normalized_df=normalized_df.reshape(67950,1,4)
#print(normalized_df)
#TTrain=np.repeat(TTrain,50)

listTest=[]
i=0
while i < (len(normalized_df)):
    listTest.append(normalized_df[i:i+50])
    i=i+50

#print(listTest)
listTest=np.stack(listTest)

length = 50
n_features = 4
model = Sequential()
model.add(LSTM(150,input_shape=(length,n_features)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['acc'])
model.compile(optimizer='adam', loss='mean_squared_error')
model.summary()
with tf.device('/gpu:0'):
    model.fit(listTest,TTrain,epochs=100,verbose=2)

    
testArr=[]
for i in range(len(XTest)):
    testArr.append(np.transpose(np.array(XTest[i])))

testArr=np.stack(testArr)
with tf.device('/cpu:0'):
    Y_hat=model.predict(testArr)

#print(Y_hat)
TTest=TTest.reshape(len(TTest),1)
#print(np.array(TTest))

dataResult=np.concatenate((Y_hat,TTest),axis=1)
#print(dataResult)

import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

plt.plot(TTest,color='green',label='Actual')
plt.plot(Y_hat,color='blue',label='Predicted')
plt.xlabel('Number')
plt.ylabel('VO2max')
plt.title('Actual vs Predicted')
plt.legend()
#plt.figure(figsize=(100,100))

#plt.show()
fig = plt.gcf()
fig.set_size_inches(20.5, 10.5)
fig.savefig('test2png.png', dpi=150)
# Out:
# ['TTest', 'TTrain', 'XTest', 'XTrain', '__globals__', '__header__', '__version__']
# TTest: (340, 1)
# TTrain: (1359, 1)
# XTrain: (1359, 1)
# XTest: (340, 1)
#              C1        C2      C3        C4
# 0      2.594557  0.459191  0.3900  0.068406
# 1      2.570753  0.496237  0.4050  0.080021
# 2      2.553465  0.533884  0.3825  0.069378
# 3      2.585183  0.476851  0.3975  0.079567
# 4      2.589196  0.526986  0.3825  0.065496
# ...         ...       ...     ...       ...
# 67945  3.516776  0.437440  0.3975  0.080801
# 67946  3.383230  0.659559  0.3825  0.072998
# 67947  3.425420  0.499233  0.3975  0.083357
# 67948  3.330528  0.516398  0.3725  0.075701
# 67949  3.444686  0.457105  0.3950  0.079806
#
# [67950 rows x 4 columns]
#              C1        C2        C3        C4
# 0      0.323124  0.251716 -0.079844 -0.000175
# 1      0.298567  0.479955 -0.075502  0.026230
# 2      0.280732  0.711891 -0.082015  0.002033
# 3      0.313454  0.360520 -0.077673  0.025197
# 4      0.317594  0.669393 -0.082015 -0.006793
# ...         ...       ...       ...       ...
# 67945  1.274541  0.117707 -0.077673  0.028002
# 67946  1.136767  1.486165 -0.082015  0.010264
# 67947  1.180292  0.498413 -0.077673  0.033813
# 67948  1.082396  0.604162 -0.084910  0.016407
# 67949  1.200168  0.238863 -0.078396  0.025741
#
# [67950 rows x 4 columns]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 150)               93000
#
#  dense (Dense)               (None, 1)                 151
#
# =================================================================
# Total params: 93,151
# Trainable params: 93,151
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 43/43 - 3s - loss: 293.8604 - 3s/epoch - 68ms/step
# Epoch 2/100
# 43/43 - 0s - loss: 74.6792 - 326ms/epoch - 8ms/step
# Epoch 3/100
# 43/43 - 0s - loss: 71.9601 - 333ms/epoch - 8ms/step
# Epoch 4/100
# 43/43 - 0s - loss: 71.8848 - 331ms/epoch - 8ms/step
# Epoch 5/100
# 43/43 - 0s - loss: 71.8198 - 333ms/epoch - 8ms/step
# Epoch 6/100
# 43/43 - 0s - loss: 71.7472 - 341ms/epoch - 8ms/step
# Epoch 7/100
# 43/43 - 0s - loss: 71.6206 - 378ms/epoch - 9ms/step
# Epoch 8/100
# 43/43 - 0s - loss: 71.2407 - 346ms/epoch - 8ms/step
# Epoch 9/100
# 43/43 - 0s - loss: 70.6106 - 366ms/epoch - 9ms/step
# Epoch 10/100
# 43/43 - 0s - loss: 69.5946 - 328ms/epoch - 8ms/step
# Epoch 11/100
# 43/43 - 0s - loss: 66.8955 - 337ms/epoch - 8ms/step
# Epoch 12/100
# 43/43 - 0s - loss: 61.4729 - 316ms/epoch - 7ms/step
# Epoch 13/100
# 43/43 - 0s - loss: 53.0883 - 333ms/epoch - 8ms/step
# Epoch 14/100
# 43/43 - 0s - loss: 44.2178 - 333ms/epoch - 8ms/step
# Epoch 15/100
# 43/43 - 0s - loss: 45.0888 - 333ms/epoch - 8ms/step
# Epoch 16/100
# 43/43 - 0s - loss: 57.1197 - 331ms/epoch - 8ms/step
# Epoch 17/100
# 43/43 - 0s - loss: 48.8792 - 334ms/epoch - 8ms/step
# Epoch 18/100
# 43/43 - 0s - loss: 45.5690 - 327ms/epoch - 8ms/step
# Epoch 19/100
# 43/43 - 0s - loss: 43.6339 - 357ms/epoch - 8ms/step
# Epoch 20/100
# 43/43 - 0s - loss: 69.0499 - 321ms/epoch - 7ms/step
# Epoch 21/100
# 43/43 - 0s - loss: 181.6632 - 326ms/epoch - 8ms/step
# Epoch 22/100
# 43/43 - 0s - loss: 70.1557 - 324ms/epoch - 8ms/step
# Epoch 23/100
# 43/43 - 0s - loss: 57.0695 - 327ms/epoch - 8ms/step
# Epoch 24/100
# 43/43 - 0s - loss: 45.7538 - 332ms/epoch - 8ms/step
# Epoch 25/100
# 43/43 - 0s - loss: 42.9704 - 335ms/epoch - 8ms/step
# Epoch 26/100
# 43/43 - 0s - loss: 44.6101 - 315ms/epoch - 7ms/step
# Epoch 27/100
# 43/43 - 0s - loss: 42.5341 - 321ms/epoch - 7ms/step
# Epoch 28/100
# 43/43 - 0s - loss: 42.3298 - 318ms/epoch - 7ms/step
# Epoch 29/100
# 43/43 - 0s - loss: 41.6427 - 335ms/epoch - 8ms/step
# Epoch 30/100
# 43/43 - 0s - loss: 41.9965 - 348ms/epoch - 8ms/step
# Epoch 31/100
# 43/43 - 0s - loss: 41.8790 - 346ms/epoch - 8ms/step
# Epoch 32/100
# 43/43 - 0s - loss: 41.7467 - 346ms/epoch - 8ms/step
# Epoch 33/100
# 43/43 - 0s - loss: 41.5569 - 345ms/epoch - 8ms/step
# Epoch 34/100
# 43/43 - 0s - loss: 42.9361 - 339ms/epoch - 8ms/step
# Epoch 35/100
# 43/43 - 0s - loss: 41.3718 - 335ms/epoch - 8ms/step
# Epoch 36/100
# 43/43 - 0s - loss: 41.2669 - 346ms/epoch - 8ms/step
# Epoch 37/100
# 43/43 - 0s - loss: 41.2241 - 303ms/epoch - 7ms/step
# Epoch 38/100
# 43/43 - 0s - loss: 41.1082 - 314ms/epoch - 7ms/step
# Epoch 39/100
# 43/43 - 0s - loss: 41.7815 - 332ms/epoch - 8ms/step
# Epoch 40/100
# 43/43 - 0s - loss: 41.1196 - 325ms/epoch - 8ms/step
# Epoch 41/100
# 43/43 - 0s - loss: 40.7026 - 313ms/epoch - 7ms/step
# Epoch 42/100
# 43/43 - 0s - loss: 40.6423 - 352ms/epoch - 8ms/step
# Epoch 43/100
# 43/43 - 0s - loss: 40.5977 - 352ms/epoch - 8ms/step
# Epoch 44/100
# 43/43 - 0s - loss: 40.4686 - 333ms/epoch - 8ms/step
# Epoch 45/100
# 43/43 - 0s - loss: 40.1874 - 336ms/epoch - 8ms/step
# Epoch 46/100
# 43/43 - 0s - loss: 40.1775 - 354ms/epoch - 8ms/step
# Epoch 47/100
# 43/43 - 0s - loss: 40.0629 - 344ms/epoch - 8ms/step
# Epoch 48/100
# 43/43 - 0s - loss: 41.2408 - 334ms/epoch - 8ms/step
# Epoch 49/100
# 43/43 - 0s - loss: 40.3438 - 345ms/epoch - 8ms/step
# Epoch 50/100
# 43/43 - 0s - loss: 39.3394 - 348ms/epoch - 8ms/step
# Epoch 51/100
# 43/43 - 0s - loss: 39.9509 - 368ms/epoch - 9ms/step
# Epoch 52/100
# 43/43 - 0s - loss: 40.0739 - 352ms/epoch - 8ms/step
# Epoch 53/100
# 43/43 - 0s - loss: 39.3918 - 305ms/epoch - 7ms/step
# Epoch 54/100
# 43/43 - 0s - loss: 40.1620 - 362ms/epoch - 8ms/step
# Epoch 55/100
# 43/43 - 0s - loss: 37.8085 - 324ms/epoch - 8ms/step
# Epoch 56/100
# 43/43 - 0s - loss: 37.6924 - 316ms/epoch - 7ms/step
# Epoch 57/100
# 43/43 - 0s - loss: 37.4720 - 332ms/epoch - 8ms/step
# Epoch 58/100
# 43/43 - 0s - loss: 37.1993 - 347ms/epoch - 8ms/step
# Epoch 59/100
# 43/43 - 0s - loss: 36.8243 - 310ms/epoch - 7ms/step
# Epoch 60/100
# 43/43 - 0s - loss: 36.5583 - 412ms/epoch - 10ms/step
# Epoch 61/100
# 43/43 - 0s - loss: 35.3579 - 328ms/epoch - 8ms/step
# Epoch 62/100
# 43/43 - 0s - loss: 35.4156 - 346ms/epoch - 8ms/step
# Epoch 63/100
# 43/43 - 0s - loss: 35.1493 - 371ms/epoch - 9ms/step
# Epoch 64/100
# 43/43 - 0s - loss: 35.5756 - 352ms/epoch - 8ms/step
# Epoch 65/100
# 43/43 - 0s - loss: 34.8481 - 372ms/epoch - 9ms/step
# Epoch 66/100
# 43/43 - 0s - loss: 35.5976 - 349ms/epoch - 8ms/step
# Epoch 67/100
# 43/43 - 0s - loss: 34.4647 - 336ms/epoch - 8ms/step
# Epoch 68/100
# 43/43 - 0s - loss: 34.3456 - 370ms/epoch - 9ms/step
# Epoch 69/100
# 43/43 - 0s - loss: 34.2687 - 328ms/epoch - 8ms/step
# Epoch 70/100
# 43/43 - 0s - loss: 34.4718 - 345ms/epoch - 8ms/step
# Epoch 71/100
# 43/43 - 0s - loss: 46.3896 - 324ms/epoch - 8ms/step
# Epoch 72/100
# 43/43 - 0s - loss: 35.2153 - 326ms/epoch - 8ms/step
# Epoch 73/100
# 43/43 - 0s - loss: 33.4006 - 325ms/epoch - 8ms/step
# Epoch 74/100
# 43/43 - 0s - loss: 33.7190 - 327ms/epoch - 8ms/step
# Epoch 75/100
# 43/43 - 0s - loss: 33.3856 - 342ms/epoch - 8ms/step
# Epoch 76/100
# 43/43 - 0s - loss: 32.9135 - 333ms/epoch - 8ms/step
# Epoch 77/100
# 43/43 - 0s - loss: 32.4210 - 353ms/epoch - 8ms/step
# Epoch 78/100
# 43/43 - 0s - loss: 34.6319 - 397ms/epoch - 9ms/step
# Epoch 79/100
# 43/43 - 0s - loss: 33.4815 - 398ms/epoch - 9ms/step
# Epoch 80/100
# 43/43 - 0s - loss: 33.0016 - 390ms/epoch - 9ms/step
# Epoch 81/100
# 43/43 - 0s - loss: 32.6053 - 412ms/epoch - 10ms/step
# Epoch 82/100
# 43/43 - 0s - loss: 30.7461 - 391ms/epoch - 9ms/step
# Epoch 83/100
# 43/43 - 0s - loss: 31.1446 - 337ms/epoch - 8ms/step
# Epoch 84/100
# 43/43 - 0s - loss: 31.3874 - 315ms/epoch - 7ms/step
# Epoch 85/100
# 43/43 - 0s - loss: 30.3115 - 313ms/epoch - 7ms/step
# Epoch 86/100
# 43/43 - 0s - loss: 28.0406 - 316ms/epoch - 7ms/step
# Epoch 87/100
# 43/43 - 0s - loss: 29.6367 - 326ms/epoch - 8ms/step
# Epoch 88/100
# 43/43 - 0s - loss: 30.7584 - 330ms/epoch - 8ms/step
# Epoch 89/100
# 43/43 - 0s - loss: 29.1510 - 310ms/epoch - 7ms/step
# Epoch 90/100
# 43/43 - 0s - loss: 29.0355 - 333ms/epoch - 8ms/step
# Epoch 91/100
# 43/43 - 0s - loss: 27.1332 - 323ms/epoch - 8ms/step
# Epoch 92/100
# 43/43 - 0s - loss: 28.1224 - 319ms/epoch - 7ms/step
# Epoch 93/100
# 43/43 - 0s - loss: 27.8845 - 316ms/epoch - 7ms/step
# Epoch 94/100
# 43/43 - 0s - loss: 26.3842 - 325ms/epoch - 8ms/step
# Epoch 95/100
# 43/43 - 0s - loss: 25.5162 - 326ms/epoch - 8ms/step
# Epoch 96/100
# 43/43 - 0s - loss: 26.5068 - 317ms/epoch - 7ms/step
# Epoch 97/100
# 43/43 - 0s - loss: 27.1884 - 333ms/epoch - 8ms/step
# Epoch 98/100
# 43/43 - 0s - loss: 26.2146 - 331ms/epoch - 8ms/step
# Epoch 99/100
# 43/43 - 0s - loss: 26.7707 - 313ms/epoch - 7ms/step
# Epoch 100/100
# 43/43 - 0s - loss: 26.3281 - 309ms/epoch - 7ms/step
# 11/11 [==============================] - 0s 9ms/step

# %%
get_available_devices()
# Out:
# ['/device:CPU:0', '/device:GPU:0']

# %%
#pd.DataFrame(dataResult).to_csv('sample.csv')
